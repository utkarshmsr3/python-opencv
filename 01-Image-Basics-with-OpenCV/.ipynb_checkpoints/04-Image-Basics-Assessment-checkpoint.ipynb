# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>

# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("../DATA/dog_backpack.jpg")

# %%
img
# Out:
# array([[[249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250],
#         ...,
#         [249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250]],
#
#        [[249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250],
#         ...,
#         [249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250]],
#
#        [[249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250],
#         ...,
#         [249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250]],
#
#        ...,
#
#        [[ 38,  41,  49],
#         [ 39,  39,  51],
#         [ 38,  37,  53],
#         ...,
#         [ 86,  80,  75],
#         [ 83,  77,  72],
#         [ 79,  75,  70]],
#
#        [[ 39,  42,  50],
#         [ 40,  40,  52],
#         [ 38,  37,  53],
#         ...,
#         [ 88,  82,  75],
#         [ 84,  78,  73],
#         [ 79,  75,  70]],
#
#        [[ 40,  43,  51],
#         [ 39,  39,  51],
#         [ 39,  38,  54],
#         ...,
#         [ 89,  83,  76],
#         [ 84,  78,  71],
#         [ 78,  75,  67]]], dtype=uint8)

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
plt.imshow(cv2.flip(img_rgb,0))

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
img_draw = img_rgb.copy()
cv2.rectangle(img_draw,pt1=(200,380),pt2=(600,720),color=(255,0,0),thickness=4)
plt.imshow(img_draw)

# %%
img.shape
# Out:
# (1401, 934, 3)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
img_draw = img_rgb.copy()
vertices = np.array([[[467,700]],[[267,500]],[[667,500]]],dtype=np.int32)
vertices.shape
cv2.polylines(img_draw,[vertices],isClosed=True,color=(0,0,255),thickness=8)
plt.imshow(img_draw)

# %% [markdown]
# ### BONUS TASK. Can you figure our how to fill in this triangle? It requires a different function that we didn't show in the lecture! See if you can use google search to find it.
#
# [CLICK ME FOR A DIRECT LINK TO THE HINT](https://docs.opencv.org/3.0-beta/modules/imgproc/doc/drawing_functions.html#fillpoly)

# %%
img_draw = img_rgb.copy()
vertices = np.array([[[467,700]],[[267,500]],[[667,500]]],dtype=np.int32)
vertices.shape
#cv2.polylines(img_draw,[vertices],isClosed=True,color=(0,0,255),thickness=200)
cv2.fillPoly(img_draw,[vertices],color=(0,0,255))
plt.imshow(img_draw)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
import cv2
import numpy as np
count = 0
def draw_circle(event,x,y,flags,param):
    global count
    if(event==cv2.EVENT_RBUTTONDOWN):
        count+=1
        print(count,"right click performed")
        cv2.circle(img_base,(x,y),radius=100,color=(0,0,255),thickness=4)
        
img_base = img.copy()
winname = 'assessment1'
cv2.namedWindow(winname=winname)
cv2.setMouseCallback(winname,draw_circle)
while(True):
    cv2.imshow(winname,img_base)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# 1 right click performed
# 2 right click performed
